# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
femaledf = pd.read_excel(r'C:\Users\urvi9\Downloads\FemaleDataset.xls', header=3)
femaledf.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                              Indicator Name     Indicator Code       1960  \
# 0  Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  67.783000
# 1  Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  45.718381
# 2  Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  33.285000
# 3  Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  39.381940
# 4  Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  39.918000
#
#         1961       1962       1963       1964       1965  ...       2014  \
# 0  68.269000  68.579000  68.992000  69.180000  69.449000  ...  78.614000
# 1  46.129297  46.490941  46.782763  47.365993  47.431575  ...  63.641430
# ...

# %%
maledf = pd.read_excel(r'C:\Users\urvi9\Downloads\MaleDataset.xls', header=3)
maledf.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                            Indicator Name     Indicator Code       1960  \
# 0  Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  60.582000
# 1  Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  42.560295
# 2  Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  31.870000
# 3  Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  36.451144
# 4  Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  36.585000
#
#         1961       1962       1963       1964       1965  ...       2014  \
# 0  60.880000  61.023000  61.372000  61.522000  61.686000  ...  72.448000
# 1  42.761640  43.133980  43.172863  43.729603  43.700803  ...  59.030487
# ...

# %%
# Melt the female dataset from wide to long format
female_long = pd.melt(femaledf, 
                      id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], 
                      var_name='Year', 
                      value_name='Life Expectancy Female')

female_long
# Out:
#                       Country Name Country Code  \
# 0                            Aruba          ABW
# 1      Africa Eastern and Southern          AFE
# 2                      Afghanistan          AFG
# 3       Africa Western and Central          AFW
# 4                           Angola          AGO
# ...                            ...          ...
# 17019                       Kosovo          XKX
# 17020                  Yemen, Rep.          YEM
# 17021                 South Africa          ZAF
# 17022                       Zambia          ZMB
# 17023                     Zimbabwe          ZWE
#
#                                  Indicator Name     Indicator Code  Year  \
# 0      Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  1960
# 1      Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  1960
# 2      Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  1960
# 3      Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  1960
# ...

# %%
male_long = pd.melt(maledf, 
                      id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], 
                      var_name='Year', 
                      value_name='Life Expectancy Male')

male_long
# Out:
#                       Country Name Country Code  \
# 0                            Aruba          ABW
# 1      Africa Eastern and Southern          AFE
# 2                      Afghanistan          AFG
# 3       Africa Western and Central          AFW
# 4                           Angola          AGO
# ...                            ...          ...
# 17019                       Kosovo          XKX
# 17020                  Yemen, Rep.          YEM
# 17021                 South Africa          ZAF
# 17022                       Zambia          ZMB
# 17023                     Zimbabwe          ZWE
#
#                                Indicator Name     Indicator Code  Year  \
# 0      Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  1960
# 1      Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  1960
# 2      Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  1960
# 3      Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  1960
# ...

# %%
columns_to_drop = ['Indicator Name', 'Indicator Code']
female_long.drop(columns=columns_to_drop, inplace=True)

columns_to_drop = ['Indicator Name', 'Indicator Code']
male_long.drop(columns=columns_to_drop, inplace=True)

# %%
male_long['Year'] = pd.to_numeric(male_long['Year'], errors='coerce')
male_long.fillna(0, inplace=True)
male_long
# Out:
#                       Country Name Country Code  Year  Life Expectancy Male
# 0                            Aruba          ABW  1960             60.582000
# 1      Africa Eastern and Southern          AFE  1960             42.560295
# 2                      Afghanistan          AFG  1960             31.870000
# 3       Africa Western and Central          AFW  1960             36.451144
# 4                           Angola          AGO  1960             36.585000
# ...                            ...          ...   ...                   ...
# 17019                       Kosovo          XKX  2023              0.000000
# 17020                  Yemen, Rep.          YEM  2023              0.000000
# 17021                 South Africa          ZAF  2023              0.000000
# 17022                       Zambia          ZMB  2023              0.000000
# 17023                     Zimbabwe          ZWE  2023              0.000000
#
# [17024 rows x 4 columns]

# %%
female_long['Year'] = pd.to_numeric(female_long['Year'], errors='coerce')
female_long.fillna(0, inplace=True)
female_long
# Out:
#                       Country Name Country Code  Year  Life Expectancy Female
# 0                            Aruba          ABW  1960               67.783000
# 1      Africa Eastern and Southern          AFE  1960               45.718381
# 2                      Afghanistan          AFG  1960               33.285000
# 3       Africa Western and Central          AFW  1960               39.381940
# 4                           Angola          AGO  1960               39.918000
# ...                            ...          ...   ...                     ...
# 17019                       Kosovo          XKX  2023                0.000000
# 17020                  Yemen, Rep.          YEM  2023                0.000000
# 17021                 South Africa          ZAF  2023                0.000000
# 17022                       Zambia          ZMB  2023                0.000000
# 17023                     Zimbabwe          ZWE  2023                0.000000
#
# [17024 rows x 4 columns]

# %%
female_long.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17024 entries, 0 to 17023
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country Name            17024 non-null  object
#  1   Country Code            17024 non-null  object
#  2   Year                    17024 non-null  int64
#  3   Life Expectancy Female  17024 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 532.1+ KB

# %%
#Merge the datasets on 'Country Name' and 'Year'
#merged_data = pd.merge(female_long, male_long, on=["Country Name", "Country Code", "Year"])
#merged_data

# %%
tempdf = pd.read_csv(r'C:\Users\urvi9\Downloads\Annual_Surface_Temperature_Change.csv')
tempdf.head()
# Out:
#    ObjectId                       Country ISO2 ISO3  \
# 0         1  Afghanistan, Islamic Rep. of   AF  AFG
# 1         2                       Albania   AL  ALB
# 2         3                       Algeria   DZ  DZA
# 3         4                American Samoa   AS  ASM
# 4         5      Andorra, Principality of   AD  AND
#
#                                            Indicator            Unit  \
# 0  Temperature change with respect to a baseline ...  Degree Celsius
# 1  Temperature change with respect to a baseline ...  Degree Celsius
# 2  Temperature change with respect to a baseline ...  Degree Celsius
# 3  Temperature change with respect to a baseline ...  Degree Celsius
# 4  Temperature change with respect to a baseline ...  Degree Celsius
#
#                                               Source CTS_Code  \
# 0  Food and Agriculture Organization of the Unite...     ECCS
# 1  Food and Agriculture Organization of the Unite...     ECCS
# ...

# %%
tempdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225 entries, 0 to 224
# Data columns (total 72 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ObjectId             225 non-null    int64
#  1   Country              225 non-null    object
#  2   ISO2                 223 non-null    object
#  3   ISO3                 225 non-null    object
#  4   Indicator            225 non-null    object
#  5   Unit                 225 non-null    object
#  6   Source               225 non-null    object
#  7   CTS_Code             225 non-null    object
#  8   CTS_Name             225 non-null    object
#  9   CTS_Full_Descriptor  225 non-null    object
#  10  F1961                188 non-null    float64
#  11  F1962                189 non-null    float64
#  12  F1963                188 non-null    float64
#  13  F1964                188 non-null    float64
#  14  F1965                188 non-null    float64
# ...

# %%
tempdf_long = pd.melt(tempdf, 
                     id_vars=['ObjectId', 'Country', 'ISO2', 'ISO3', 'Indicator', 'Unit', 'Source', 
                              'CTS_Code', 'CTS_Name', 'CTS_Full_Descriptor'], 
                     value_vars=[f'F{year}' for year in range(1961, 2023)],  
                     var_name='Year', 
                     value_name='Temperature Change')

# Adjust the 'Year' column to extract just the year number
tempdf_long['Year'] = tempdf_long['Year'].str[1:]  # Remove 'F'
tempdf_long.head()
# Out:
#    ObjectId                       Country ISO2 ISO3  \
# 0         1  Afghanistan, Islamic Rep. of   AF  AFG
# 1         2                       Albania   AL  ALB
# 2         3                       Algeria   DZ  DZA
# 3         4                American Samoa   AS  ASM
# 4         5      Andorra, Principality of   AD  AND
#
#                                            Indicator            Unit  \
# 0  Temperature change with respect to a baseline ...  Degree Celsius
# 1  Temperature change with respect to a baseline ...  Degree Celsius
# 2  Temperature change with respect to a baseline ...  Degree Celsius
# 3  Temperature change with respect to a baseline ...  Degree Celsius
# 4  Temperature change with respect to a baseline ...  Degree Celsius
#
#                                               Source CTS_Code  \
# 0  Food and Agriculture Organization of the Unite...     ECCS
# 1  Food and Agriculture Organization of the Unite...     ECCS
# ...

# %%
columns_to_drop = ['ObjectId', 'ISO2','CTS_Code','CTS_Name','Unit','CTS_Full_Descriptor','Source']
tempdf_long.drop(columns=columns_to_drop, inplace=True)
tempdf_long['Year'] = pd.to_numeric(tempdf_long['Year'], errors='coerce')
tempdf_long.fillna(0, inplace=True)
tempdf_long
# Out:
#                             Country ISO3  \
# 0      Afghanistan, Islamic Rep. of  AFG
# 1                           Albania  ALB
# 2                           Algeria  DZA
# 3                    American Samoa  ASM
# 4          Andorra, Principality of  AND
# ...                             ...  ...
# 13945                Western Sahara  ESH
# 13946                         World  WLD
# 13947                Yemen, Rep. of  YEM
# 13948                        Zambia  ZMB
# 13949                      Zimbabwe  ZWE
#
#                                                Indicator  Year  \
# 0      Temperature change with respect to a baseline ...  1961
# 1      Temperature change with respect to a baseline ...  1961
# 2      Temperature change with respect to a baseline ...  1961
# 3      Temperature change with respect to a baseline ...  1961
# 4      Temperature change with respect to a baseline ...  1961
# ...                                                  ...   ...
# ...

# %%
#merge both datasets based on 'Country' and 'Year'
#merged_df = pd.merge(merged_data, tempdf_long, 
#                     how='inner', 
#                     left_on=['Country Name', 'Year'], 
#                     right_on=['Country', 'Year'])

#merged_df

# %%
male_long.to_excel('male_long.xlsx', index=False)
female_long.to_excel('female_long.xlsx', index=False)
tempdf_long.to_excel('tempdf_long.xlsx', index=False)

# %%
#male_long.to_csv('male_long.xlsx', index=False)
#female_long.to_csv('female_long.xlsx', index=False)
#tempdf_long.to_csv('tempdf_long.xlsx', index=False)
